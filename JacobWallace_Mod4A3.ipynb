# %% [markdown]
# # Assignment 2
# ## Jacob Wallace

# %%
## Imports
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
#nltk.download('punkt')
#nltk.download('wordnet')
#nltk.download('omw-1.4')

# %%
# Read Data from CSV
amazMusical_df = pd.read_csv('archive/Musical_instruments_reviews.csv')

# %%
amazMusical_df.head()
# Out:
#        reviewerID        asin  \
# 0  A2IBPI20UZIR0U  1384719342
# 1  A14VAT5EAX3D9S  1384719342
# 2  A195EZSQDW3E21  1384719342
# 3  A2C00NNG1ZQQG2  1384719342
# 4   A94QU4C90B1AX  1384719342
#
#                                        reviewerName   helpful  \
# 0  cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                              Jake  [13, 14]
# 2                     Rick Bennette "Rick Bennette"    [1, 1]
# 3                         RustyBill "Sunday Rocker"    [0, 0]
# 4                                     SEAN MASLANKA    [0, 0]
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary  unixReviewTime   reviewTime
# 0                                   good      1393545600  02 28, 2014
# 1                                   Jake      1363392000  03 16, 2013
# 2                   It Does The Job Well      1377648000  08 28, 2013
# 3          GOOD WINDSCREEN FOR THE MONEY      1392336000  02 14, 2014
# 4  No more pops when I record my vocals.      1392940800  02 21, 2014

# %%
summary = amazMusical_df['summary']
summary = ' '.join(str(s) for s in summary)
len(summary)
# Out:
# 260099

# %%
# Tokenize Summary
tokens = word_tokenize(summary)
len(tokens)
# Out:
# 51293

# %%
# Stem the Tokens
st = LancasterStemmer()
stems = [st.stem(tok) for tok in tokens]
len(stems)
# Out:
# 51293

# %%
# Lemmatize the stemmed tokens
lem = WordNetLemmatizer()
lemms = [lem.lemmatize(stem) for stem in stems] 
len(lemms)
# Out:
# 51293

# %%
data = {'Tokens': tokens,
        'Stems': stems,
        'Lemmenize': lemms}
processed_df = pd.DataFrame(data,columns=["Tokens","Stems","Lemmenize"])

# %%
processed_df.head(50)
# Out:
#         Tokens       Stems   Lemmenize
# 0         good        good        good
# 1         Jake         jak         jak
# 2           It          it          it
# 3         Does         doe         doe
# 4          The         the         the
# 5          Job         job         job
# 6         Well         wel         wel
# 7         GOOD        good        good
# 8   WINDSCREEN  windscreen  windscreen
# 9          FOR         for         for
# 10         THE         the         the
# 11       MONEY       money       money
# 12          No          no          no
# 13        more         mor         mor
# 14        pops         pop         pop
# 15        when        when        when
# 16           I           i           i
# 17      record      record      record
# 18          my          my          my
# 19      vocals         voc         voc
# 20           .           .           .
# 21         The         the         the
# 22        Best        best        best
# 23       Cable        cabl        cabl
# 24     Monster       monst       monst
# 25    Standard    standard    standard
# 26         100         100         100
# 27           -           -           -
# 28          21          21          21
# 29           '           '           '
# 30  Instrument      instru      instru
# 31       Cable        cabl        cabl
# 32         Did         did         did
# 33         n't         n't         n't
# 34         fit         fit         fit
# 35          my          my          my
# 36        1996        1996        1996
# 37      Fender        fend        fend
# 38       Strat       strat       strat
# 39         ...         ...         ...
# 40       Great         gre         gre
# 41       cable        cabl        cabl
# 42        Best        best        best
# 43  Instrument      instru      instru
# 44      Cables        cabl        cabl
# 45          On          on          on
# 46         The         the         the
# 47      Market      market      market
# 48         One          on          on
# 49          of          of          of
